# %% [markdown]
# # EDA with Visualization
# Explore launch characteristics and landing success.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('../data/sample_launches.csv')
df.groupby('LaunchSite').size().plot(kind='bar', title='Launch Count by Site')
plt.tight_layout()
plt.show()
