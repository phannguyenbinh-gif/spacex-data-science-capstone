# %% [markdown]
# # Folium Launch Site Map
# Interactive geospatial view of representative Falcon 9 launch sites.

# %%
import folium
m=folium.Map(location=[29,-90], zoom_start=3)
for name,lat,lon in [('KSC LC-39A',28.608,-80.604),('CCAFS',28.562,-80.577),('VAFB SLC-4E',34.633,-120.611)]:
    folium.Marker([lat,lon],popup=name).add_to(m)
m
