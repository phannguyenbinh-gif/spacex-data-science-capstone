# %% [markdown]
# # Data Collection with SpaceX API
# Collect and normalize past launch data.

# %%
import requests, pandas as pd
url='https://api.spacexdata.com/v4/launches/past'
r=requests.get(url, timeout=30)
r.raise_for_status()
df=pd.json_normalize(r.json())
print(df.shape)
df.head()
